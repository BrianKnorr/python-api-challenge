# %%
import matplotlib.pyplot as plt
import requests
import pandas as pd
from citipy import citipy
import random
# from config import api_key

# %%
city = citipy.nearest_city(-80,140)

# %%
city.city_name, city.country_code
# Out:
# ('hobart', 'au')

# %%
random.uniform(-90,90)
# Out:
# 67.09310891271119

# %%
cities = []
for i in range(500):
    lon = random.uniform(-90,90)
    lat = random.uniform(-180,180)
    city = citipy.nearest_city(lon,lat)
    cities = cities + [city]

# %%
[ (i.city_name,i.country_code) for i in cities]

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
api_key = "22a4f5c84bff15691eb1d36606f064f8"
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
resp = requests.get(query_url+"Paris"+"&country_code='FR'").json()
resp

# %%
weatherDatabyCity = []
for city in cities:
    cityWeather = requests.get(query_url+city.city_name+"&country_code="+city.country_code).json()
    weatherDatabyCity = weatherDatabyCity + [ cityWeather]
weatherDatabyCity
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6556/4231753411.py in <module>
#       1 weatherDatabyCity = []
#       2 for city in cities:
# ----> 3     cityWeather = requests.get(query_url+city.city_name+"&country_code="+city.country_code).json()
#       4     weatherDatabyCity = weatherDatabyCity + [ cityWeather]
#       5 weatherDatabyCity
#
# AttributeError: 'str' object has no attribute 'city_name'

# %%
weatherDatabyCityerDatabyCity)
# Out:
# [{'coord': {'lon': 107.359, 'lat': 34.3659}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 0.86, 'feels_like': 0.86, 'temp_min': 0.86, 'temp_max': 0.86, 'pressure': 1028, 'humidity': 60, 'sea_level': 1028, 'grnd_level': 960}, 'visibility': 10000, 'wind': {'speed': 0.51, 'deg': 329, 'gust': 0.58}, 'clouds': {'all': 37}, 'dt': 1644367600, 'sys': {'country': 'CN', 'sunrise': 1644363731, 'sunset': 1644402447}, 'timezone': 28800, 'id': 1809263, 'name': 'Guozhen', 'cod': 200}, {'coord': {'lon': -17.3389, 'lat': 66.0449}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': -2.05, 'feels_like': -9.05, 'temp_min': -2.05, 'temp_max': -2.05, 'pressure': 982, 'humidity': 96, 'sea_level': 982, 'grnd_level': 981}, 'visibility': 145, 'wind': {'speed': 10.69, 'deg': 5, 'gust': 12.9}, 'snow': {'1h': 0.64}, 'clouds': {'all': 100}, 'dt': 1644367226, 'sys'
# ...

# %%
cities = ["Paris", "London", "Oslo", "Beijing"]

# set up lists to hold reponse info
lat = []
temp = []

# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    lat.append(response['coord']['lat'])
    temp.append(response['main']['temp'])

print(f"The latitude information received is: {lat}")
print(f"The temperature information received is: {temp}")
# Out:
# The latitude information received is: [48.8534, 51.5085, 59.9127, 39.9075]
# The temperature information received is: [5.43, 9.68, 2.27, -4.06]

# %%
weatherDatabyCity
# Out:
# [{'coord': {'lon': 107.359, 'lat': 34.3659},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 0.86,
#    'feels_like': 0.86,
#    'temp_min': 0.86,
#    'temp_max': 0.86,
#    'pressure': 1028,
#    'humidity': 60,
#    'sea_level': 1028,
#    'grnd_level': 960},
#   'visibility': 10000,
#   'wind': {'speed': 0.51, 'deg': 329, 'gust': 0.58},
#   'clouds': {'all': 37},
#   'dt': 1644367600,
#   'sys': {'country': 'CN', 'sunrise': 1644363731, 'sunset': 1644402447},
#   'timezone': 28800,
#   'id': 1809263,
#   'name': 'Guozhen',
#   'cod': 200},
#  {'coord': {'lon': -17.3389, 'lat': 66.0449},
#   'weather': [{'id': 601,
#     'main': 'Snow',
#     'description': 'snow',
#     'icon': '13n'}],
#   'base': 'stations',
#   'main': {'temp': -2.05,
#    'feels_like': -9.05,
#    'temp_min': -2.05,
#    'temp_max': -2.05,
#    'pressure': 982,
#    'humidity': 96,
# ...
